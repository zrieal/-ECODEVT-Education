# %% [markdown]
# # Control Flow

# %% [markdown]
# Key Concepts
# - Conditional statements: if, elif, and else to make decisions
# - Comparison operators: ==, !=, >, <, >=, <=
# - Logical operators: and, or, not
# - Loops: for and while loops
# - Control statements: break, continue, and pass

# %% [markdown]
# Skills
# - Writing conditional logic to guide code execution
# - Iterating over sequences (lists, strings) with for loops
# - Using while loops to handle indefinite iteration

# %% [markdown]
# ## Conditional Statements

# %%
# Example of conditional statements
x = 10

# Basic if-elif-else structure
if x > 0:
    print("x is positive")
elif x == 0:
    print("x is zero")
else:
    print("x is negative")

# %%
# Example with multiple conditions
y = -5

if y > 0:
    print("y is positive")
elif y < 0:
    print("y is negative")
else:
    print("y is zero")

# %%
# Nested conditional statements
a = 7
b = 3

if a > b:
    if a - b > 5:
        print("a is significantly larger than b")
    else:
        print("a is larger than b but not by much")
else:
    print("a is not larger than b")

# %% [markdown]
# ## Comparison Operators

# %%
# Example of comparison operators
a = 5
b = 10

print(a == b)  # False
print(a != b)  # True
print(a > b)   # False
print(a < b)   # True
print(a >= b)  # False
print(a <= b)  # True

# %% [markdown]
# ## Logical Operators

# %%
# Example of logical operators
a = True
b = False

print(a and b)  # False
print(a or b)   # True
print(not a)    # False

# %% [markdown]
# ## Loops: `for` and `while`

# %%
# Example of a for loop
# A for loop is used for iterating over a sequence (like a list, tuple, dictionary, set, or string)
# Here, we iterate over a range of numbers from 0 to 4
for i in range(5):
    print(i)

# %%
# Example of a while loop
# A while loop will continue to execute as long as the condition is True
# Here, we start with count = 0 and increment it by 1 until it reaches 5
count = 0
while count < 5:
    print(count)
    count += 1

# %%
# Another example of a while loop
# Using a while loop to iterate until a user input is 'exit'
user_input = ""
while user_input != "exit":
    user_input = input("Enter something (type 'exit' to stop): ")
    print("You entered:", user_input)

# %% [markdown]
# ## Control Statements: break, continue, and pass
# - The break statement is used to exit the loop when a certain condition is met
# - The continue statement is used to skip the rest of the code inside the loop for the current iteration only
# - The pass statement is a null operation; it does nothing and is used as a placeholder

# %%
# Using break
print("Example 1: Using break")
for i in range(10):
    if i == 7:
        break  # Exit the loop when i is 7
    print(i)

# %%
# Using continue
print("\nExample 2: Using continue")
for i in range(10):
    if i == 3:
        continue  # Skip the rest of the code inside the loop for this iteration when i is 3
    print(i)

# %%
# Using pass
print("\nExample 3: Using pass")
for i in range(10):
    if i == 5:
        pass  # Do nothing, just a placeholder
    print(i)

# %%
# Combining break, continue, and pass
print("\nExample 4: Combining break, continue, and pass")
for i in range(10):
    if i == 3:
        continue  # Skip the rest of the code inside the loop for this iteration when i is 3
    if i == 7:
        break  # Exit the loop when i is 7
    if i == 5:
        pass  # Do nothing, just a placeholder
    print(i)

# %% [markdown]
# # Guide Questions

# %% [markdown]
# ⭐️ Writing Conditional Logic to Guide Code Execution

# %%
# Conditional logic example
age = 20

if age < 18:
    print("You are a minor.")
elif 18 <= age < 65:
    print("You are an adult.")
else:
    print("You are a senior.")

# %% [markdown]
# ⭐️ Iterating Over Sequences (Lists, Strings) with for Loops

# %%
# Iterating over a list
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)

# Iterating over a string
word = "hello"
for letter in word:
    print(letter)

# %% [markdown]
# ⭐️ Using while Loops to Handle Indefinite Iteration

# %% [markdown]
# while loops are used to execute a block of code as long as a condition is true. They are useful for situations where you don't know in advance how many times you need to iterate.

# %%
# Using a while loop
count = 0
while count < 5:
    print("Count is:", count)
    count += 1
# Explanation:
# The loop continues to execute as long as count is less than 5.
# Inside the loop, it prints the current value of count and then increments count by 1.

# %% [markdown]
# # Assessments

# %% [markdown]
# ## Question 1

# %% [markdown]
# Write a Python function called grade_classifier that accepts a student's score (0-100) as input and prints:
#
# - "A" for scores 90 and above
# - "B" for scores 80 to 89
# - "C" for scores 70 to 79
# - "D" for scores 60 to 69
# - "F" for scores below 60
#
# Extend the function so that it also returns "Invalid score" for any inputs outside the range 0-100.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Create a function `can_vote` that takes two parameters: age and citizen. The function should return True if the person can vote (age 18 or above and a citizen), and False otherwise.

# %% [markdown]
# ## Question 3

# %% [markdown]
# Write a function `sum_of_evens` that accepts a list of numbers and returns the sum of all the even numbers in the list using a for loop.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Write a function weather_advice that takes temperature and weather (e.g., "rainy", "sunny") as input and prints:
#
# - "Wear a coat" if the temperature is below 50°F
# - "Take an umbrella" if the weather is rainy
# - "Enjoy the sunshine!" if the weather is sunny and temperature is above 70°F

# %% [markdown]
# # Checkpoint Questions

# %% [markdown]
# ## Checkpoint 1

# %% [markdown]
# Modify the grade_classifier function to handle letter grades using different grading schemes (e.g., percentages or GPA scales) used at your institution. Write a short reflection on how grading systems may vary and the potential impact on students. Research different countries' grading systems (e.g., the U.S., Germany, Japan). How do the variations in grading systems affect student performance and perceptions of academic success? Write a 200-word response based on your findings.

# %% [markdown]
# ## Checkpoint 2

# %% [markdown]
# Adapt the `can_vote` function for a real-world scenario by researching the voting age and citizenship requirements for three different countries. Document your findings and explain how these differences impact democratic participation. Reflect on how laws governing the right to vote differ across countries and how this influences civic engagement. Write a 300-word essay comparing the voting age and requirements in three different countries and how these rules shape political involvement.

# %% [markdown]
# ## Checkpoint 3

# %% [markdown]
# Reflect on a situation in your life where you had to make a decision based on multiple conditions (e.g., deciding between job offers, planning a trip). Write Python code using conditional statements (if, elif, else) to represent this decision-making process. Write a reflection discussing how you structured the loop to reflect real-world unpredictability. Think about an activity in your daily life that involves repetitive tasks, like meal preparation or exercise. Describe how you could use a while loop to model the steps, including any decision points (e.g., stopping conditions) involved.
#
# Requirements:
# - Write a Python function called personal_decision() that takes relevant factors (e.g., salary, distance, weather, etc.) as inputs.
# - Use conditional logic to output the final decision.

# %% [markdown]
# ## Checkpoint 4

# %% [markdown]
# Write a Python function loan_eligibility() that checks if a person is eligible for a loan based on three inputs: credit_score, income, and debt. The rules are:
#
# - The person is eligible if their credit score is above 700 and their income is greater than PHP 40000 or their debt is less than PHP 10000.
# - The function should return "Eligible" or "Not Eligible."
#
# After writing the function, provide a 200-word reflection discussing how logical operators can simplify complex financial decision-making in loan eligibility systems.
